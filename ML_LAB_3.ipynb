# %% [markdown]
# In this practical I have implemented Linear Regression (Supervised Learning)

# %%
from sklearn import linear_model
import matplotlib.pyplot as plt
import numpy as np
import random

# %%
# let's create a linear function with some error called f
def f(x):
    res = x* 25 + 3
    error = res * random.uniform(-0.15, 0.15) # you can play with the error to see how it affects the result
    return res + error

# %%
values = []
# now using f we are going to create 100 values.
for i in range(0, 100):
    x = random.uniform(1, 100)
    y = f(x)
    values.append((x, y))
    regr = linear_model.LinearRegression()

# %%
x, y = zip(*values)
print(x)
print(y)
max_x = max(x)
min_x = min(x)
# Out:
# (11.61061796964851, 78.79993942078539, 84.33365044350846, 8.769810835366155, 61.995662208630655, 22.344701697006467, 37.54374062172276, 49.622331034138575, 8.56355083283393, 88.24091986024494, 29.447512597567247, 74.23468915044847, 22.388428200143697, 89.56966830224972, 22.622054997332466, 81.53557622869731, 46.92455390560475, 68.73443619878582, 38.950580879611834, 75.48288634193734, 84.24182421668371, 45.49476018513862, 65.01711263708756, 81.0462374019092, 29.63102926084367, 60.51958961817853, 79.10163217450615, 12.760427736519599, 82.59821091409681, 42.01607529390482, 94.80435411147654, 58.92132596623872, 63.6186040797605, 86.99404372376009, 2.1957539754970514, 16.3068249268716, 47.71031589246205, 18.635869196995856, 65.69052557193142, 30.4790542355046, 92.5041997527894, 12.681464992285742, 84.85553817487586, 64.53352670774201, 54.73120551149816, 99.73121643845991, 14.206170852590615, 88.51312249606558, 71.736937689131, 51.87102093379277, 6.036192226254468, 75.36084080737551, 4.018436529491886, 53.51478163750031, 68.13450679848576, 74.22569302289536, 5.568660177345212, 2.1495996519848966, 61.58383923520141, 33.90323704257523, 91.22493643772745, 73.85978022679622, 15.00713285007781, 50.958702637301926, 92.13659752030952, 75.20852913849812, 99.46625321376835, 67.61443593432168, 74.49315405556649, 22.77513608895292, 34.63461128781334, 80.44181229253047, 46.40718319773802, 81.16793537886433, 16.512233598448866, 95.45626695143471, 27.76742741298371, 55.18447458052087, 12.349283935345124, 34.58598902580685, 61.06774973723894, 5.1732872011933075, 40.81583076825738, 78.15141177760056, 63.3010042156404, 56.36789864451163, 30.68862470121604, 15.782638683723505, 74.03298717276668, 37.84214733090441, 14.630742956868627, 82.55033733259307, 30.67925437952228, 4.577315839630817, 52.53512101088138, 52.041406506597575, 77.25197954252928, 18.2593839460752, 11.570440516315433, 64.64294358037435)
# (306.60006165235706, 1818.788362208812, 2320.9400817067535, 207.0011668090295, 1580.1960624469446, 507.08141816577654, 1052.523244060841, 1076.9904436248598, 228.6709086884381, 1899.7788400646505, 845.5167214068274, 2066.356815033389, 634.2047164350262, 1964.3317168373928, 578.402194410606, 1794.0190592282124, 1035.2708535346994, 1950.8585700597018, 999.3204544676485, 1830.2460744945067, 2361.351749723846, 1037.0717467520092, 1447.36429517816, 1750.8188650879356, 749.6936924431408, 1578.5537263491703, 1733.4877687812602, 366.52343858486427, 2095.716705722838, 960.385103534024, 2323.0510183705055, 1523.920239787355, 1368.3743271879948, 1993.2157974662266, 52.60986796442672, 397.87245058963697, 1373.412625478265, 526.3087875052483, 1729.8027533431741, 773.0922997091992, 1983.8654959596274, 294.6003025782246, 2396.2680923860307, 1852.8915164961275, 1490.419773887196, 2809.7295974693106, 395.2447332292574, 2267.114099044459, 1829.0036031465643, 1172.8517191979251, 149.25901517741235, 1928.1987721336513, 118.84289136345399, 1362.601065942825, 1773.4914151451899, 2016.3639434457125, 129.50794357354195, 61.86410591630206, 1740.857344628038, 742.9975025299793, 2010.5910850694393, 2116.5245050977474, 398.6647734693402, 1456.0491937540098, 2471.463747006416, 1883.5779356512035, 2172.0596469722163, 1463.3405814346409, 1640.4005932978143, 495.9079898556735, 759.4712288539004, 2230.4884306716613, 1158.9980774883516, 1755.9078775341463, 395.71097367624685, 2453.617367582742, 687.4071328274562, 1248.1978036272483, 346.39211454089025, 779.9839760804542, 1410.5505866285928, 144.35314577531253, 1107.485697011329, 2165.3937168647344, 1349.990622982688, 1386.4331895448404, 712.094356542546, 364.2576620767129, 1625.6757955406229, 919.8745362329224, 419.5852996596657, 1773.0252143494438, 707.7657391208108, 133.5163293382545, 1393.7273696550035, 1181.7314566117889, 1685.0328601810154, 411.73019906432313, 281.2072288205313, 1598.70380425319)

# %%
# split the values in training and test data.

train_data_X = list(map(lambda x: [x], list(x[:-20])))
train_data_Y = list(y[:-20])

test_data_X = list(map(lambda x: [x], list(x[-20:])))
test_data_Y = list(y[-20:])

# %%
# feed the linear regression with the train data to obtain a model.
regr.fit(train_data_X, train_data_Y)
# check that the coeffients are the expected ones.
m = regr.coef_[0]
b = regr.intercept_
print(' y = {0} * x + {1}'.format(m, b))
# Out:
#  y = 24.4952729911684 * x + 18.79389040545584

# %%
# now we are going to plot the points and the model obtained
plt.scatter(x, y, color='blue') 
plt.plot([min_x, max_x], [b, m*max_x + b], 'r')
plt.title('Fitted linear regression', fontsize=18)
plt.xlabel('x', fontsize=15)
plt.ylabel('y', fontsize=15)
# Out:
# Text(0, 0.5, 'y')

# %%
# The mean squared error
print("Mean squared error: %.2f" % np.mean((regr.predict(test_data_X) - test_data_Y) ** 2))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % regr.score(test_data_X, test_data_Y))
# Out:
# Mean squared error: 254306.67
# Variance score: 0.64
