# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("breast-cancer.csv")

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.iloc[:,1:].describe()
# Out:
#        radius_mean  texture_mean  perimeter_mean    area_mean  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# ...

# %%
df = df[['radius_mean','texture_mean','perimeter_mean','area_mean']]
df.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean
# 0        17.99         10.38          122.80     1001.0
# 1        20.57         17.77          132.90     1326.0
# 2        19.69         21.25          130.00     1203.0
# 3        11.42         20.38           77.58      386.1
# 4        20.29         14.34          135.10     1297.0

# %%
for i in df.columns[1:]:
    df.boxplot(i,by='radius_mean')
    #df.boxplot(i)

# %%
plt.figure(figsize=(10,6))
plt.scatter(df['area_mean'],df['texture_mean'],c = df['radius_mean'])
plt.grid(True)
plt.title("Scattered plot")
plt.ylabel("area mean")
plt.xlabel("texture mean")
plt.show()

# %%
def correlation_matrix(df):
    from matplotlib import pyplot as plt
    from matplotlib import cm as cm
    fig = plt.figure(figsize=(16,12))
    ax1 = fig.add_subplot(111)
    cmap = cm.get_cmap('jet',30)
    cax = ax1.imshow(df.corr(),interpolation="nearest" ,cmap = cmap)
    ax1.grid(True)
    plt.title('Data set feature correlation\n',fontsize=15)
    labels=df.columns
    ax1.set_xticklabels(labels,fontsize=12)
    ax1.set_yticklabels(labels,fontsize=12)
    #fig.colorbar(cax,ticks=[0.1*i for i in range(-11,11)])
    plt.show()

    
correlation_matrix(df)
# Out:
# C:\Users\astha\AppData\Local\Temp/ipykernel_26048/3244381426.py:11: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(labels,fontsize=12)
# C:\Users\astha\AppData\Local\Temp/ipykernel_26048/3244381426.py:12: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_yticklabels(labels,fontsize=12)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
x = df.drop('radius_mean',axis=1)
y = df['radius_mean']

# %%
x = scaler.fit_transform(x)

# %%
dfnew = pd.DataFrame(data=x,columns=df.columns[1:])

# %%
dfnew.describe()
# Out:
#        texture_mean  perimeter_mean     area_mean
# count  5.690000e+02    5.690000e+02  5.690000e+02
# mean   6.868164e-17   -1.248757e-16 -2.185325e-16
# std    1.000880e+00    1.000880e+00  1.000880e+00
# min   -2.229249e+00   -1.984504e+00 -1.454443e+00
# 25%   -7.259631e-01   -6.919555e-01 -6.671955e-01
# 50%   -1.046362e-01   -2.359800e-01 -2.951869e-01
# 75%    5.841756e-01    4.996769e-01  3.635073e-01
# max    4.651889e+00    3.976130e+00  5.250529e+00

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=None)
dfnew_pca = pca.fit(dfnew)

# %%
plt.figure(figsize=(9,5))
plt.scatter(x=[i+1 for i in range(len(dfnew_pca.explained_variance_ratio_))],
y = dfnew_pca.explained_variance_ratio_,
s=200,alpha=0.75,c='red',edgecolor='m')
plt.grid(True)
plt.xticks([i+1 for i in range(len(dfnew_pca.explained_variance_ratio_))])
plt.yticks(fontsize=15)
plt.show()

# %%
dfx_trans = pca.transform(dfnew)
dfx_trans = pd.DataFrame(data=dfx_trans)
dfx_trans.head(10)
# Out:
#           0         1         2
# 0  0.723311 -2.511874 -0.218525
# 1  2.235110 -1.261794  0.151078
# 2  2.223383 -0.385605 -0.005789
# 3 -0.799727  0.588662 -0.118218
# 4  1.948014 -2.005668  0.023252
# 5 -0.893471 -0.545192 -0.088466
# 6  1.528262 -0.429205 -0.031695
# 7 -0.060498  0.409845 -0.100543
# 8 -0.157891  0.696102 -0.136871
# 9 -0.146342  1.246689 -0.118532

# %%
plt.figure(figsize=(10,6))
plt.scatter(dfx_trans[0],dfx_trans[1],c=df['radius_mean'],edgecolors='m',alpha=0.75,s=150)
plt.grid(True)
plt.title("Class seperation")
plt.xlabel("PC-1",fontsize = 13)
plt.ylabel("PC-2",fontsize = 13)
plt.show()
